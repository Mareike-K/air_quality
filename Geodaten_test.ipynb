# %%
from data_combine_clean import data_import, data_cleaning, add_geodata

# %%
df = data_import()
# Out:
# /Users/mareikekeller/air_quality/data_combine_clean.py:37: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   return pd.concat(dataframes, ignore_index=True)

# %%
df = data_cleaning(df)
# Out:
# ✅ Datei wurde gespeichert: ./data/city_per_country.csv
# ✅ Datei wurde gespeichert: ./data/cleaned_data.csv

# %%
df = add_geodata(df)

# %%
df
# Out:
#               Date Country         City  ...  wind-speed  Latitude  Longitude
# 0       2014-12-29      AT       vienna  ...         NaN  48.20849   16.37208
# 1       2014-12-29      AU     brisbane  ...         NaN -27.46794  153.02809
# 2       2014-12-29      BE     brussels  ...         NaN  50.85045    4.34878
# 3       2014-12-29      BO   cochabamba  ...         NaN -17.38950  -66.15680
# 4       2014-12-29      BR    são paulo  ...         NaN -23.54750  -46.63611
# ...            ...     ...          ...  ...         ...       ...        ...
# 231568  2025-02-20      UG      kampala  ...         2.3   0.31628   32.58219
# 231569  2025-02-20      UZ     tashkent  ...         1.5  41.26465   69.21627
# 231570  2025-02-20      VN        hanoi  ...         1.0  21.02450  105.84117
# 231571  2025-02-20      XK     pristina  ...         0.1  42.67272   21.16688
# 231572  2025-02-20      ZA  vereeniging  ...         1.0 -26.67313   27.92615
#
# [231573 rows x 26 columns]
