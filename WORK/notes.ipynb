# %% [markdown]
# TODO's:
#
#
# - README aufhübschen (datahowto integrieren, wiebke)
# - aufräumen (inkl WORK in gitignore)
#
# - Evtl. zweiten Data-Ordner anlegen, so dass einer für Inputdaten ist und einer für Output, das man entweder anschauen oder weiterverwenden möchte? Beispiel: Listen der Städte in den einzelnen Clustern.
#
# - Populationsdaten überprüfen, vielleicht Datenquelle ändern?
# Da sind jetzt z.T. unrealistische Zahlen drin:
# Isfahan hat ca. 2,5 Mio Einwohner, nicht 15 Mio
# Teheran hat 8 Mio, nicht 260.000
# Dubai hat 3 Mio, nicht 130.000
# Chongqing hat 30 Mio, nicht 380.000
# Santiago hat 6 Mio, nicht 150.000
# Außerdem: Eine ganze Reihe von chinesischen Städten hat einheitlich 3.724.844 Einwohner. Das lag daran, dass georaphisch Nähe als Proxy gewählt wurde, oder?
# Die Populationsdaten wurden am Ende der Clusteranalyse für die Interpretation verwendet. Entweder der Aspekt muss aus der Clusteranalyse wieder raus (was nicht schwer ist), oder die Populationsdaten müssen noch mal korrigiert werden.
#
# - Dokumentation der Struktur und Funktionsweise von data_preparation.py im Notebook 0_datacleaning.ipynb überprüfen (Wiebke)
#
# - Spalte "Date" erscheint immer noch nicht, auch wenn das Löschen auskommentiert ist. Warum?
#
#
#
# FÜR SPÄTER
# - Mareike erklärt Wiebke nochmal lambda-Funktionen
#
#
# ERLEDIGT
# - Zielvariable für Klassifikation definieren (PM25 für Luftqualität) (Mareike)
# - Clusteranalysen zusammenfassen und aufhübschen (Mareike)
# - EDA finalisieren (Mareike)
# - date-Spalte drinlassen (modul convert_date, Wiebke)
# - tbd: Script für automatische Projektstruktur-Erstellung finden (Wiebke, nee lassen wir)
#
# - EDA: Tabelle in Markdown (Auswertung describe wetter)
#
# - EDA: Wetterdaten in der Schleife analysieren (Mareike)
#
# -DATEN: REdundante Spalte (wind-speed, Temperature, pressuer, wind-gust) löschen in der funktion (wiebke)
#     hat bisher irgendwie nciht geklappt
#
# -DATEN:  Check Bevölkerungsdatern: fehlen 78% der Städte???? (wiebke)
#     Wahrscheinlich fehlen die nicht, sondern die Bevölkerungsdaten sind nur für besteimmte Jahre da...
#     WEg finden das Jahr davor oder danach zu nehmen
#     -> Imputieren
#
# Clusteranalyse (Mareike)
#     - aufsetzen,so dass sie funktioniert01
# FÜR DIE PRÄSI:
# - Ziel des Projektes: ÜBEN
# - Zielgruppe der Präsi: stackfuel und keine Vorstände
#
# Struktur Präsi
#     12' (max 10 Charts)
#
#     - Ziel
#         Lerne, lernen, lernen
#         Fragestellung (Schadstoffe/ Pandemie)
#         Unser Vorgehen (iterrativ und agil)
#     - Datenquellen
#         air
#         github
#         dataio
#         meteostat
#     - Aufbereitung
#         funktionen
#         script
#         tests
#     - finaler Datensatz
#         umfang (screen)
#     - EDA
#         - reduzierter datensatz
#         - features: Wetter und Schadstoffe
#         - Umgang mit fehlenden Werten/ Spalten
#         - Korrelationen
#         - Visualisierung Geodaten
#     - Analysen
#         zeitreihen (Pandemie ohne Effekt,
#         Zwischenfazit:
#         zeitreihen: Schadstoffe im Jahresverlauf)
#         cluster
#
#     - Findings und Ausblick
#         bisher kein Effekt
#         Schadstoffcluster
#
#         Learnings:
#             Datenanreicherung
#             Scripte und Tests schreiben
#
#         Ausblick:
#             Wie verhalten sich die einzelnen Cluster im Bezug auf die Pandemie
# - Sind die Grenzwerte in den Ländern unterschiedlich?
# - Datenwörterbuch anlegen
# - Länderkürzel vervollständigen (Mareike)
# - Daten für die übrigen Jahre laden (Wiebke)
# - Datensatz teilen (Spalte Specie)
# - Datenwörterbuch schön machen (Wiebke)
# - Daten für die übrigen Jahre laden (Mareike)
# - Zielfragestellung finalisieren (alle)
#     => Gibt es Zusammenhänge zwischen schadstoffbelasung in der Luft und der Pandemie?
#     => Wenn ja , welche?
#     => Sind die Erkenntnisse nutzbar, um Maßnahmen zur zukünftigen Senkung der Schadstoffbelastung abzuleiten?
# - EDA vorbereiten und mit kleinem Datensatz testen (Mareike)
# - Rausfinden, wie die Varianz definiert ist (Antwort abwarten, Mareike), cancelled
# - Mittwoch: Besprechen, wie wir mit den neuen Variablen umgehen, die beim Erstellen des Gesamtdatensatzes aufgetaucht sind (d, pol, psi; Schreibung wind-gust vs wind gust vereinheitlichen)
#     - rausfinden, was die neuen Spalten bedeuten: d, poll, (wiebke) canceled
#     - wie wird der psi in Singapur berechnen? Und wie wird dieser in den AQI umgerechnet (wiebke) canceld
#     - wie wir wird windspeed gemessen? Datenwörterbuch updaten (wiebke)
#     - Wind-gust und wind gust - beheben (Mareike)
# - EDA machen (Mareike)
# - Donnerstag: drei Folien für Freitag
# - Daten vorbereiten für große EDA (wiebke)
#     - Länder/ Städte definieren für finale (erl.)
#     - eine Stadt/ Land mit meisten Messwerten anhand 24/25 (erl.)
#     - Einwohnerzahlen dazu holen
#     - Tabellen umbauen je Jahr (tbd)
#     - counts löschen aber dokumentieren (erl.)
#     - ein Datensatz für alle Jahre (erl.)
# - Wollen wir die 'data-combine_clean. umbennen? nur data? (erl.)
# - airq-Seite lesen (alle)
#     - Geo-Daten schon im Data_import (Mareike) (erl)
#     Daten:
#  alles neu:
#  erst mal im TEst und noch nicht final in die FUnktion:
#     - Wetter dazu und ggf. wind-speed aus den ursprungsdaten rausnehmen (Wiebke) (erl)
#         - Datenwörterbuch aktualisieren (erl)
#     - Datum trennen schon im data-cleaning (wiebke) (erl)
#     - In den Daten chekcn, wir Wind-speed gemessen/ angegegben wird und Wörterbuch aktualisieren (wiebke) (erl)
#     - Einwohner-df integrieren und zwar wann? (wiebke) (erl)
#     - städte reduzieren optional raus am anfang (sinnvolles reduzieren spätrer in der bearbeitung)    (erl)
#     file_info umbenennen in files (wiebke) (erl)

# %%
Die Grenzwerte für Feinstaubbelastungen (PM10 und PM2,5) sind in der EU und Deutschland durch verschiedene Richtlinien und Verordnungen geregelt. Hier sind die aktuellen Grenzwerte:

PM10 (Partikel mit einem Durchmesser von ≤ 10 µm)
Tagesmittelwert: 50 µg/m³ (darf höchstens 35 Mal im Jahr überschritten werden)
Jahresmittelwert: 40 µg/m³
PM2,5 (Partikel mit einem Durchmesser von ≤ 2,5 µm)
Jahresmittelwert: 20 µg/m³ (seit 2020 in der EU)
Neue WHO-Empfehlungen (2021)
Die Weltgesundheitsorganisation (WHO) hat 2021 strengere Richtwerte vorgeschlagen:

PM10: 15 µg/m³ (Jahresmittel), 45 µg/m³ (Tagesmittel)
PM2,5: 5 µg/m³ (Jahresmittel), 15 µg/m³ (Tagesmittel)
Diese WHO-Werte sind jedoch nicht rechtlich bindend, sondern dienen als Empfehlung für bessere Luftqualität.

# %% [markdown]
# Der Begriff "NEPH" steht im Zusammenhang mit der Luftqualität für Nephelometer-Messungen. Ein Nephelometer ist ein Gerät, das die Lichtstreuung an Aerosolpartikeln misst und damit Rückschlüsse auf die Trübung der Luft sowie die Feinstaubbelastung ermöglicht.
#
# Bedeutung in der Luftqualitätsmessung:
# NEPH-Werte werden oft in 1/Mm (pro Megameter) angegeben und beschreiben die Lichtstreuung durch Partikel in der Luft.
# Hohe NEPH-Werte deuten auf eine stärkere Lufttrübung hin, was meist mit einer höheren Feinstaubkonzentration korreliert.
# Nephelometer werden häufig für PM2.5- und PM10-Messungen sowie für Analysen zur Sichtweite und zur Überwachung von Luftverschmutzung eingesetzt.

# %% [markdown]
# ### 🧠 LaTeX-Cheat-Sheet für Inline-Formeln in Jupyter
#
# _Nutzbar mit_ `$...$` _im Fließtext_
#
# #### 🔤 Griechische Buchstaben
# ```
# $\alpha$, $\beta$, $\gamma$, $\delta$, $\epsilon$, $\lambda$, $\mu$, $\sigma$, $\theta$
# $\Gamma$, $\Delta$, $\Lambda$, $\Sigma$, $\Theta$
# ```
#
# #### 🧮 Hoch- und Tiefstellung
# ```
# $x^2$ → x²
# $e^{-\lambda t}$ → e hoch -λt
# $x_1$, $y_{t+1}$ → x₁, y Index t+1
# ```
#
# #### ➗ Brüche & Wurzeln
# ```
# $\frac{a}{b}$ → a/b
# $\sqrt{x}$ → √x
# $\sqrt[n]{x}$ → n-te Wurzel von x
# ```
#
# #### ➕ Operatoren & Symbole
# ```
# $\sum$, $\prod$, $\int$ → Summenzeichen, Produkt, Integral
# $\in$, $\notin$, $\subset$, $\supset$ → Mengenbeziehungen
# $\approx$, $\neq$, $\leq$, $\geq$ → Vergleichsoperatoren
# $\rightarrow$, $\Leftarrow$, $\leftrightarrow$ → Pfeile
# ```
#
# #### 🔧 Text im Mathemodus
# ```
# \text{ppm} → $\text{ppm}$
# ```
#
# ---
#
# **💡 Beispiel:**
#
# ```markdown
# Die Konzentration ändert sich mit $\lambda = \frac{\Delta C}{\Delta t}$ pro Zeiteinheit.
# ```
#
# > Die Konzentration ändert sich mit λ = ΔC⁄Δt pro Zeiteinheit.
